# %%
import pandas as pd
import numpy as np
import os
import csv

# %%
import app.preprocessing as prep

# %%
project_path = os.getcwd()

# %%
data_path = os.path.join(project_path, 'data')
train_dataset_path = os.path.join(data_path, 'multinli_1.0_train.txt')

# %%
with open(train_dataset_path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter="\t", quotechar=None)
    lines = []
    for line in reader:
        lines.append(line)

# %%
lines
# Out:
# [['gold_label',
#   'sentence1_binary_parse',
#   'sentence2_binary_parse',
#   'sentence1_parse',
#   'sentence2_parse',
#   'sentence1',
#   'sentence2',
#   'promptID',
#   'pairID',
#   'genre',
#   'label1',
#   'label2',
#   'label3',
#   'label4',
#   'label5'],
#  ['neutral',
#   '( ( Conceptually ( cream skimming ) ) ( ( has ( ( ( two ( basic dimensions ) ) - ) ( ( product and ) geography ) ) ) . ) )',
#   '( ( ( Product and ) geography ) ( ( are ( what ( make ( cream ( skimming work ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (JJ Conceptually) (NN cream) (NN skimming)) (VP (VBZ has) (NP (NP (CD two) (JJ basic) (NNS dimensions)) (: -) (NP (NN product) (CC and) (NN geography)))) (. .)))',
#   '(ROOT (S (NP (NN Product) (CC and) (NN geography)) (VP (VBP are) (SBAR (WHNP (WP what)) (S (VP (VBP make) (NP (NP (NN cream)) (VP (VBG skimming) (NP (NN work)))))))) (. .)))',
#   'Conceptually cream skimming has two basic dimensions - product and geography.',
#   'Product and geography are what make cream skimming work. ',
#   '31193',
#   '31193n',
#   'government',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( you ( ( know ( during ( ( ( the season ) and ) ( i guess ) ) ) ) ( at ( at ( ( your level ) ( uh ( you ( ( ( lose them ) ( to ( the ( next level ) ) ) ) ( if ( ( if ( they ( decide ( to ( recall ( the ( the ( parent team ) ) ) ) ) ) ) ) ( ( the Braves ) ( decide ( to ( call ( to ( ( recall ( a guy ) ) ( from ( ( triple A ) ( ( ( then ( ( a ( double ( A guy ) ) ) ( ( goes up ) ( to ( replace him ) ) ) ) ) and ) ( ( a ( single ( A guy ) ) ) ( ( goes up ) ( to ( replace him ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )',
#   '( You ( ( ( ( lose ( the things ) ) ( to ( the ( following level ) ) ) ) ( if ( ( the people ) recall ) ) ) . ) )',
#   '(ROOT (S (NP (PRP you)) (VP (VBP know) (PP (IN during) (NP (NP (DT the) (NN season)) (CC and) (NP (FW i) (FW guess)))) (PP (IN at) (IN at) (NP (NP (PRP$ your) (NN level)) (SBAR (S (INTJ (UH uh)) (NP (PRP you)) (VP (VBP lose) (NP (PRP them)) (PP (TO to) (NP (DT the) (JJ next) (NN level))) (SBAR (IN if) (S (SBAR (IN if) (S (NP (PRP they)) (VP (VBP decide) (S (VP (TO to) (VP (VB recall) (NP (DT the) (DT the) (NN parent) (NN team)))))))) (NP (DT the) (NNPS Braves)) (VP (VBP decide) (S (VP (TO to) (VP (VB call) (S (VP (TO to) (VP (VB recall) (NP (DT a) (NN guy)) (PP (IN from) (NP (NP (RB triple) (DT A)) (SBAR (S (S (ADVP (RB then)) (NP (DT a) (JJ double) (NNP A) (NN guy)) (VP (VBZ goes) (PRT (RP up)) (S (VP (TO to) (VP (VB replace) (NP (PRP him))))))) (CC and) (S (NP (DT a) (JJ single) (NNP A) (NN guy)) (VP (VBZ goes) (PRT (RP up)) (S (VP (TO to) (VP (VB replace) (NP (PRP him))))))))))))))))))))))))))))',
#   '(ROOT (S (NP (PRP You)) (VP (VBP lose) (NP (DT the) (NNS things)) (PP (TO to) (NP (DT the) (JJ following) (NN level))) (SBAR (IN if) (S (NP (DT the) (NNS people)) (VP (VBP recall))))) (. .)))',
#   'you know during the season and i guess at at your level uh you lose them to the next level if if they decide to recall the the parent team the Braves decide to call to recall a guy from triple A then a double A guy goes up to replace him and a single A guy goes up to replace him',
#   'You lose the things to the following level if the people recall.',
#   '101457',
#   '101457e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( One ( of ( our number ) ) ) ( ( will ( ( ( carry out ) ( your instructions ) ) minutely ) ) . ) )',
#   '( ( ( A member ) ( of ( my team ) ) ) ( ( will ( ( execute ( your orders ) ) ( with ( immense precision ) ) ) ) . ) )',
#   '(ROOT (S (NP (NP (CD One)) (PP (IN of) (NP (PRP$ our) (NN number)))) (VP (MD will) (VP (VB carry) (PRT (RP out)) (NP (PRP$ your) (NNS instructions)) (ADVP (RB minutely)))) (. .)))',
#   '(ROOT (S (NP (NP (DT A) (NN member)) (PP (IN of) (NP (PRP$ my) (NN team)))) (VP (MD will) (VP (VB execute) (NP (PRP$ your) (NNS orders)) (PP (IN with) (NP (JJ immense) (NN precision))))) (. .)))',
#   'One of our number will carry out your instructions minutely.',
#   'A member of my team will execute your orders with immense precision.',
#   '134793',
#   '134793e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( How ( ( ( do you ) know ) ? ) ) ( ( All this ) ( ( ( is ( their information ) ) again ) . ) ) )',
#   '( ( This information ) ( ( belongs ( to them ) ) . ) )',
#   '(ROOT (S (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP you)) (VP (VB know))) (. ?)) (NP (PDT All) (DT this)) (VP (VBZ is) (NP (PRP$ their) (NN information)) (ADVP (RB again))) (. .)))',
#   '(ROOT (S (NP (DT This) (NN information)) (VP (VBZ belongs) (PP (TO to) (NP (PRP them)))) (. .)))',
#   'How do you know? All this is their information again.',
#   'This information belongs to them.',
#   '37397',
#   '37397e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( yeah ( i ( ( tell you ) ( what ( ( though ( if ( you ( go ( price ( some ( of ( those ( tennis shoes ) ) ) ) ) ) ) ) ) ( i ( can ( see ( why ( now ( you ( know ( they ( 're ( ( getting up ) ( in ( the ( hundred ( dollar range ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )",
#   '( ( The ( tennis shoes ) ) ( ( have ( ( a range ) ( of prices ) ) ) . ) )',
#   "(ROOT (S (VP (VB yeah) (S (NP (FW i)) (VP (VB tell) (NP (PRP you)) (SBAR (WHNP (WP what)) (S (SBAR (RB though) (IN if) (S (NP (PRP you)) (VP (VBP go) (VP (VB price) (NP (NP (DT some)) (PP (IN of) (NP (DT those) (NN tennis) (NNS shoes)))))))) (NP (FW i)) (VP (MD can) (VP (VB see) (SBAR (WHADVP (WRB why)) (S (ADVP (RB now)) (NP (PRP you)) (VP (VBP know) (SBAR (S (NP (PRP they)) (VP (VBP 're) (VP (VBG getting) (PRT (RP up)) (PP (IN in) (NP (DT the) (CD hundred) (NN dollar) (NN range)))))))))))))))))))",
#   '(ROOT (S (NP (DT The) (NN tennis) (NNS shoes)) (VP (VBP have) (NP (NP (DT a) (NN range)) (PP (IN of) (NP (NNS prices))))) (. .)))',
#   "yeah i tell you what though if you go price some of those tennis shoes i can see why now you know they're getting up in the hundred dollar range",
#   'The tennis shoes have a range of prices.',
#   '50563',
#   '50563n',
#   'telephone',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( ( my walkman ) ( broke ( so ( i ( 'm ( upset ( now ( i ( just ( have ( to ( ( turn ( the stereo ) ) ( up ( real loud ) ) ) ) ) ) ) ) ) ) ) ) ) )",
#   "( ( ( ( I ( 'm ( upset ( that ( ( my walkman ) broke ) ) ) ) ) and ) ( now ( I ( have ( to ( ( turn ( the stereo ) ) ( up ( really loud ) ) ) ) ) ) ) ) . )",
#   "(ROOT (S (NP (PRP$ my) (NN walkman)) (VP (VBD broke) (SBAR (IN so) (S (NP (FW i)) (VP (VBP 'm) (ADJP (VBN upset) (SBAR (RB now) (S (NP (FW i)) (ADVP (RB just)) (VP (VBP have) (S (VP (TO to) (VP (VB turn) (NP (DT the) (NN stereo)) (ADVP (RB up) (RB real) (JJ loud)))))))))))))))",
#   "(ROOT (S (S (NP (PRP I)) (VP (VBP 'm) (ADJP (VBN upset) (SBAR (IN that) (S (NP (PRP$ my) (NN walkman)) (VP (VBD broke))))))) (CC and) (S (ADVP (RB now)) (NP (PRP I)) (VP (VBP have) (S (VP (TO to) (VP (VB turn) (NP (DT the) (NN stereo)) (ADVP (RB up) (RB really) (JJ loud))))))) (. .)))",
#   "my walkman broke so i'm upset now i just have to turn the stereo up real loud",
#   "I'm upset that my walkman broke and now I have to turn the stereo up really loud.",
#   '110116',
#   '110116e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   '( But ( ( a ( few ( Christian mosaics ) ) ) ( ( survive ( above ( ( the apse ) ( ( ( is ( ( the Virgin ) ( with ( the ( infant Jesus ) ) ) ) ) , ) ( with ( ( ( the ( Archangel Gabriel ) ) ( to ( the right ) ) ) ( -LRB- ( ( ( his companion ) ( ( ( ( Michael , ) ( to ( the left ) ) ) , ) ( has ( vanished ( save ( for ( ( a ( few feathers ) ) ( from ( his wings ) ) ) ) ) ) ) ) ) -RRB- ) ) ) ) ) ) ) ) . ) ) )',
#   '( ( Most ( of ( the ( Christian mosaics ) ) ) ) ( ( were ( destroyed ( by Muslims ) ) ) . ) )',
#   '(ROOT (S (CC But) (NP (DT a) (JJ few) (JJ Christian) (NNS mosaics)) (VP (VBP survive) (PP (IN above) (NP (NP (DT the) (NN apse)) (SBAR (S (VP (VBZ is) (NP (NP (DT the) (NN Virgin)) (PP (IN with) (NP (DT the) (JJ infant) (NN Jesus)))) (, ,) (PP (IN with) (NP (NP (DT the) (NNP Archangel) (NNP Gabriel)) (PP (TO to) (NP (DT the) (NN right))) (PRN (-LRB- -LRB-) (NP (NP (PRP$ his) (NN companion)) (SBAR (S (NP (NP (NNP Michael)) (, ,) (PP (TO to) (NP (DT the) (NN left))) (, ,)) (VP (VBZ has) (VP (VBN vanished) (S (VP (VB save) (PP (IN for) (NP (NP (DT a) (JJ few) (NNS feathers)) (PP (IN from) (NP (PRP$ his) (NNS wings)))))))))))) (-RRB- -RRB-)))))))))) (. .)))',
#   '(ROOT (S (NP (NP (JJS Most)) (PP (IN of) (NP (DT the) (JJ Christian) (NNS mosaics)))) (VP (VBD were) (VP (VBN destroyed) (PP (IN by) (NP (NNPS Muslims))))) (. .)))',
#   'But a few Christian mosaics survive above the apse is the Virgin with the infant Jesus, with the Archangel Gabriel to the right (his companion Michael, to the left, has vanished save for a few feathers from his wings).',
#   'Most of the Christian mosaics were destroyed by Muslims.  ',
#   '42487',
#   '42487n',
#   'travel',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( -LRB- ( ( ( Read ( for ( ( ( Slate 's ) take ) ( on ( ( Jackson 's ) findings ) ) ) ) ) . ) -RRB- ) )",
#   "( Slate ( ( had ( ( an opinion ) ( on ( ( Jackson 's ) findings ) ) ) ) . ) )",
#   "(ROOT (S (-LRB- -LRB-) (VP (VB Read) (PP (IN for) (NP (NP (NP (NNP Slate) (POS 's)) (NN take)) (PP (IN on) (NP (NP (NNP Jackson) (POS 's)) (NNS findings)))))) (. .) (-RRB- -RRB-)))",
#   "(ROOT (S (NP (NNP Slate)) (VP (VBD had) (NP (NP (DT an) (NN opinion)) (PP (IN on) (NP (NP (NNP Jackson) (POS 's)) (NNS findings))))) (. .)))",
#   "(Read  for Slate 's take on Jackson's findings.)",
#   "Slate had an opinion on Jackson's findings.",
#   '1069',
#   '1069e',
#   'slate',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( ( Gays and ) lesbians ) . )',
#   '( Heterosexuals . )',
#   '(ROOT (NP (NP (NP (NNS Gays)) (CC and) (NP (NNS lesbians))) (. .)))',
#   '(ROOT (NP (NNS Heterosexuals) (. .)))',
#   'Gays and lesbians.',
#   'Heterosexuals.',
#   '23505',
#   '23505c',
#   'slate',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( At ( ( the end ) ( of Rue ) ) ) ( ( des Francs-Bourgeois ) ( ( is ( what ( many ( consider ( to ( ( be ( ( ( ( ( the ( city 's ) ) ( ( most handsome ) ( residential square ) ) ) , ) ( the ( Place ( des Vosges ) ) ) ) , ) ) ( with ( its ( stone ( and ( red ( brick facades ) ) ) ) ) ) ) ) ) ) ) ) . ) ) )",
#   '( ( Place ( des Vosges ) ) ( ( is ( ( constructed entirely ) ( of ( gray marble ) ) ) ) . ) )',
#   "(ROOT (S (PP (IN At) (NP (NP (DT the) (NN end)) (PP (IN of) (NP (NNP Rue))))) (NP (NNP des) (NNP Francs-Bourgeois)) (VP (VBZ is) (SBAR (WHNP (WP what)) (S (NP (DT many)) (VP (VBP consider) (S (VP (TO to) (VP (VB be) (NP (NP (NP (DT the) (NN city) (POS 's)) (ADJP (RBS most) (JJ handsome)) (JJ residential) (NN square)) (, ,) (NP (DT the) (NNP Place) (NNP des) (NNPS Vosges)) (, ,)) (PP (IN with) (NP (PRP$ its) (NN stone) (CC and) (JJ red) (NN brick) (NNS facades)))))))))) (. .)))",
#   '(ROOT (S (NP (NNP Place) (FW des) (NNP Vosges)) (VP (VBZ is) (VP (VBN constructed) (ADVP (RB entirely)) (PP (IN of) (NP (JJ gray) (NN marble))))) (. .)))',
#   "At the end of Rue des Francs-Bourgeois is what many consider to be the city's most handsome residential square, the Place des Vosges, with its stone and red brick facades.",
#   'Place des Vosges is constructed entirely of gray marble.',
#   '60529',
#   '60529c',
#   'travel',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( I ( ( ( ( ( burst ( through ( ( a set ) ( of ( cabin doors ) ) ) ) ) , ) and ) ( fell ( to ( the ground ) ) ) ) - ) )',
#   '( I ( ( ( ( burst ( through ( the doors ) ) ) and ) ( fell down ) ) . ) )',
#   '(ROOT (S (NP (PRP I)) (VP (VP (VBP burst) (PP (IN through) (NP (NP (DT a) (NN set)) (PP (IN of) (NP (NN cabin) (NNS doors)))))) (, ,) (CC and) (VP (VBD fell) (PP (TO to) (NP (DT the) (NN ground))))) (: -)))',
#   '(ROOT (S (NP (PRP I)) (VP (VP (VBP burst) (PP (IN through) (NP (DT the) (NNS doors)))) (CC and) (VP (VBD fell) (PRT (RP down)))) (. .)))',
#   'I burst through a set of cabin doors, and fell to the ground-',
#   'I burst through the doors and fell down.',
#   '55785',
#   '55785e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( Fun ( for ( ( adults and ) children ) ) ) . )',
#   '( ( Fun ( for ( only children ) ) ) . )',
#   '(ROOT (S (VP (VB Fun) (PP (IN for) (NP (NNS adults) (CC and) (NNS children)))) (. .)))',
#   '(ROOT (S (VP (VB Fun) (PP (IN for) (NP (JJ only) (NNS children)))) (. .)))',
#   'Fun for adults and children.',
#   'Fun for only children.',
#   '11877',
#   '11877c',
#   'travel',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( It ( ( ( ( 's not ) ( that ( ( ( the questions ) ( they asked ) ) ( ( were n't ) ( ( interesting or ) legitimate ) ) ) ) ) ( -LRB- ( ( though ( most ( ( did fall ) ( under ( ( ( the category ) ( of already ) ) ( ( asked and ) answered ) ) ) ) ) ) -RRB- ) ) ) . ) )",
#   '( ( All ( of ( the questions ) ) ) ( ( ( were interesting ) ( according ( to ( ( a ( focus group ) ) ( consulted ( on ( the subject ) ) ) ) ) ) ) . ) )',
#   "(ROOT (S (NP (PRP It)) (VP (VBZ 's) (RB not) (SBAR (IN that) (S (NP (NP (DT the) (NNS questions)) (SBAR (S (NP (PRP they)) (VP (VBD asked))))) (VP (VBD were) (RB n't) (ADJP (JJ interesting) (CC or) (JJ legitimate))))) (PRN (-LRB- -LRB-) (SBAR (IN though) (S (NP (JJS most)) (VP (VBD did) (NP (NN fall)) (PP (IN under) (NP (NP (DT the) (NN category)) (PP (IN of) (ADVP (RB already))) (VP (VBN asked) (CC and) (VBN answered))))))) (-RRB- -RRB-))) (. .)))",
#   '(ROOT (S (NP (NP (DT All)) (PP (IN of) (NP (DT the) (NNS questions)))) (VP (VBD were) (ADJP (JJ interesting)) (PP (VBG according) (PP (TO to) (NP (NP (DT a) (NN focus) (NN group)) (VP (VBN consulted) (PP (IN on) (NP (DT the) (NN subject)))))))) (. .)))',
#   "It's not that the questions they asked weren't interesting or legitimate (though most did fall under the category of already asked and answered).",
#   'All of the questions were interesting according to a focus group consulted on the subject.',
#   '32819',
#   '32819n',
#   'slate',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   '( Thebes ( ( ( ( ( held ( onto power ) ) ( until ( the ( 12th Dynasty ) ) ) ) , ) ( when ( ( ( ( its ( first king ) ) , ) ( ( Amenemhet ( Iwho reigned ) ) ( between ( 1980 ( 1951 b.c. ) ) ) ) ) ( established ( ( a capital ) ( near Memphis ) ) ) ) ) ) . ) )',
#   '( ( ( The capital ) ( near Memphis ) ) ( ( ( ( lasted ( only half ) ) ( a century ) ) ( before ( ( its inhabitants ) ( ( abandoned it ) ( for ( the ( next capital ) ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (NNS Thebes)) (VP (VBD held) (PP (IN onto) (NP (NN power))) (PP (IN until) (NP (DT the) (JJ 12th) (NN Dynasty))) (, ,) (SBAR (WHADVP (WRB when)) (S (NP (NP (PRP$ its) (JJ first) (NN king)) (, ,) (NP (NP (NNP Amenemhet) (NNP Iwho) (NNP reigned)) (PP (IN between) (NP (CD 1980) (CD 1951) (NNS b.c.))))) (VP (VBD established) (NP (NP (DT a) (NN capital)) (PP (IN near) (NP (NNP Memphis)))))))) (. .)))',
#   '(ROOT (S (NP (NP (DT The) (NN capital)) (PP (IN near) (NP (NNP Memphis)))) (VP (VBD lasted) (NP (QP (RB only) (PDT half))) (NP (DT a) (NN century)) (SBAR (IN before) (S (NP (PRP$ its) (NN inhabitants)) (VP (VBD abandoned) (NP (PRP it)) (PP (IN for) (NP (DT the) (JJ next) (NN capital))))))) (. .)))',
#   'Thebes held onto power until the 12th Dynasty, when its first king, Amenemhet Iwho reigned between 1980 1951 b.c. established a capital near Memphis.',
#   'The capital near Memphis lasted only half a century before its inhabitants abandoned it for the next capital. ',
#   '52772',
#   '52772n',
#   'travel',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( ( ( ( I ( ( do n't ) ( mean ( to ( be ( glib ( about ( your concerns ) ) ) ) ) ) ) ) , ) but ) ( ( if ( I ( were you ) ) ) ( , ( I ( might ( be ( more ( concerned ( about ( ( the ( near-term ( rate implications ) ) ) ( of ( this ( $ 1 ) ) ) ) ) ) ) ) ) ) ) ) ) . )",
#   '( I ( ( am ( ( concerned ( more ( about ( your issues ) ) ) ) ( than ( the ( near-term ( rate implications ) ) ) ) ) ) . ) )',
#   "(ROOT (S (S (NP (PRP I)) (VP (VBP do) (RB n't) (VP (VB mean) (S (VP (TO to) (VP (VB be) (VP (VBN glib) (PP (IN about) (NP (PRP$ your) (NNS concerns)))))))))) (, ,) (CC but) (S (SBAR (IN if) (S (NP (PRP I)) (VP (VBD were) (NP (PRP you))))) (, ,) (NP (PRP I)) (VP (MD might) (VP (VB be) (ADJP (RBR more) (JJ concerned) (PP (IN about) (NP (NP (DT the) (JJ near-term) (NN rate) (NNS implications)) (PP (IN of) (NP (DT this) ($ $) (CD 1))))))))) (. .)))",
#   '(ROOT (S (NP (PRP I)) (VP (VBP am) (VP (VBN concerned) (ADVP (RBR more) (PP (IN about) (NP (PRP$ your) (NNS issues)))) (PP (IN than) (NP (DT the) (JJ near-term) (NN rate) (NNS implications))))) (. .)))',
#   "I don't mean to be glib about your concerns, but if I were you, I might be more concerned about the near-term rate implications of this $1.",
#   'I am concerned more about your issues than the near-term rate implications.',
#   '102489',
#   '102489c',
#   'government',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( Issues ( in ( Data Synthesis ) ) ) . )',
#   '( ( Problems ( in ( data synthesis ) ) ) . )',
#   '(ROOT (NP (NP (NNS Issues)) (PP (IN in) (NP (NNP Data) (NNPS Synthesis))) (. .)))',
#   '(ROOT (NP (NP (NNS Problems)) (PP (IN in) (NP (NN data) (NN synthesis))) (. .)))',
#   'Issues in Data Synthesis.',
#   'Problems in data synthesis.',
#   '81785',
#   '81785e',
#   'government',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( well ( you ( ( see ( that ( on television ) ) ) also ) ) )',
#   '( You ( ( can ( ( ( see ( that ( on television ) ) ) , ) ( as well ) ) ) . ) )',
#   '(ROOT (ADJP (RB well) (SBAR (S (NP (PRP you)) (VP (VBP see) (NP (NP (DT that)) (PP (IN on) (NP (NN television)))) (ADVP (RB also)))))))',
#   '(ROOT (S (NP (PRP You)) (VP (MD can) (VP (VB see) (NP (NP (DT that)) (PP (IN on) (NP (NN television)))) (, ,) (ADVP (RB as) (RB well)))) (. .)))',
#   'well you see that on television also',
#   'You can see that on television, as well.',
#   '16915',
#   '16915e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( ( Vrenna and ) I ) ( both ( ( fought ( ( ( him and ) he ) ( nearly ( took us ) ) ) ) . ) ) )',
#   '( ( Neither ( ( Vrenna nor ) myself ) ) ( ( ( have ever ) ( fought him ) ) . ) )',
#   '(ROOT (S (NP (NNP Vrenna) (CC and) (PRP I)) (DT both) (VP (VBD fought) (SBAR (S (NP (PRP him) (CC and) (PRP he)) (ADVP (RB nearly)) (VP (VBD took) (NP (PRP us)))))) (. .)))',
#   '(ROOT (S (NP (CC Neither) (NP (NNP Vrenna)) (CC nor) (NP (PRP myself))) (VP (VBP have) (ADVP (RB ever)) (VP (VBN fought) (NP (PRP him)))) (. .)))',
#   'Vrenna and I both fought him and he nearly took us.',
#   'Neither Vrenna nor myself have ever fought him.',
#   '56687',
#   '56687c',
#   'fiction',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( ( This analysis ) pooled ) ( ( ( estimates ( from ( these ( two studies ) ) ) ) ( to ( ( develop ( a ( C-R function ) ) ) ( ( linking PM ) ( to ( chronic bronchitis ) ) ) ) ) ) . ) )',
#   '( ( The analysis ) ( ( proves ( that ( there ( ( ( is ( ( no link ) ( between PM ) ) ) and ) bronchitis ) ) ) ) . ) )',
#   '(ROOT (S (NP (NP (DT This) (NN analysis)) (VP (VBN pooled))) (VP (VBZ estimates) (PP (IN from) (NP (DT these) (CD two) (NNS studies))) (S (VP (TO to) (VP (VB develop) (NP (DT a) (JJ C-R) (NN function)) (S (VP (VBG linking) (NP (NNP PM)) (PP (TO to) (NP (JJ chronic) (NNS bronchitis))))))))) (. .)))',
#   '(ROOT (S (NP (DT The) (NN analysis)) (VP (VBZ proves) (SBAR (IN that) (S (NP (EX there)) (VP (VP (VBZ is) (NP (NP (DT no) (NN link)) (PP (IN between) (NP (NNP PM))))) (CC and) (VP (VBZ bronchitis)))))) (. .)))',
#   'This analysis pooled estimates from these two studies to develop a C-R function linking PM to chronic bronchitis.',
#   'The analysis proves that there is no link between PM and bronchitis.',
#   '101211',
#   '101211c',
#   'government',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   '( He ( ( ( ( turned and ) smiled ) ( at Vrenna ) ) . ) )',
#   '( He ( ( smiled ( at ( Vrenna ( who ( was ( ( walking ( slowly ( behind him ) ) ) ( with ( her mother ) ) ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (PRP He)) (VP (VBD turned) (CC and) (VBD smiled) (PP (IN at) (NP (NNP Vrenna)))) (. .)))',
#   '(ROOT (S (NP (PRP He)) (VP (VBD smiled) (PP (IN at) (NP (NP (NNP Vrenna)) (SBAR (WHNP (WP who)) (S (VP (VBD was) (VP (VBG walking) (ADVP (RB slowly) (PP (IN behind) (NP (PRP him)))) (PP (IN with) (NP (PRP$ her) (NN mother)))))))))) (. .)))',
#   'He turned and smiled at Vrenna.',
#   'He smiled at Vrenna who was walking slowly behind him with her mother.',
#   '62897',
#   '62897n',
#   'fiction',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( We ( ( sought ( to ( identify ( practices ( that ( ( were commonly ) ( implemented ( by ( ( the agencies ) ( within ( the ( past ( 5 years ) ) ) ) ) ) ) ) ) ) ) ) ) . ) )',
#   '( We ( want ( to ( identify ( practices ( commonly ( used ( by ( agencies ( in ( the ( last ( 5 years ) ) ) ) ) ) ) ) ) ) ) ) )',
#   '(ROOT (S (NP (PRP We)) (VP (VBD sought) (S (VP (TO to) (VP (VB identify) (NP (NP (NNS practices)) (SBAR (WHNP (WDT that)) (S (VP (VBD were) (ADVP (RB commonly)) (VP (VBN implemented) (PP (IN by) (NP (NP (DT the) (NNS agencies)) (PP (IN within) (NP (DT the) (JJ past) (CD 5) (NNS years)))))))))))))) (. .)))',
#   '(ROOT (S (NP (PRP We)) (VP (VBP want) (S (VP (TO to) (VP (VB identify) (NP (NP (NNS practices)) (VP (ADVP (RB commonly)) (VBN used) (PP (IN by) (NP (NP (NNS agencies)) (PP (IN in) (NP (DT the) (JJ last) (CD 5) (NNS years)))))))))))))',
#   'We sought to identify practices that were commonly implemented by the agencies within the past 5 years.',
#   'We want to identify practices commonly used by agencies in the last 5 years',
#   '38518',
#   '38518e',
#   'government',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( The ( other men ) ) ( shuffled . ) )',
#   '( ( The ( other men ) ) ( ( were ( shuffled around ) ) . ) )',
#   '(ROOT (S (NP (DT The) (JJ other) (NNS men)) (VP (VBD shuffled)) (. .)))',
#   '(ROOT (S (NP (DT The) (JJ other) (NNS men)) (VP (VBD were) (VP (VBN shuffled) (PRT (RP around)))) (. .)))',
#   'The other men shuffled.',
#   'The other men were shuffled around.',
#   '138444',
#   '138444e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( States ( ( must ( ( show ( ( reasonable progress ) ( in ( their ( state ( implementation plans ) ) ) ) ) ) ( toward ( ( the ( ( congressionally mandated ) goal ) ) ( of ( returning ( to ( ( natural conditions ) ( in ( national ( parks ( and ( wilderness areas ) ) ) ) ) ) ) ) ) ) ) ) ) . ) )',
#   '( ( ( Itis ( not necessary ) ) ( for ( there ( to ( be ( any improvement ) ) ) ) ) ) . )',
#   '(ROOT (S (NP (NNPS States)) (VP (MD must) (VP (VB show) (NP (NP (JJ reasonable) (NN progress)) (PP (IN in) (NP (PRP$ their) (NN state) (NN implementation) (NNS plans)))) (PP (IN toward) (NP (NP (DT the) (ADJP (RB congressionally) (VBN mandated)) (NN goal)) (PP (IN of) (S (VP (VBG returning) (PP (TO to) (NP (NP (JJ natural) (NNS conditions)) (PP (IN in) (NP (JJ national) (NNS parks) (CC and) (NN wilderness) (NNS areas)))))))))))) (. .)))',
#   '(ROOT (S (VP (VB Itis) (ADJP (RB not) (JJ necessary)) (SBAR (IN for) (S (NP (EX there)) (VP (TO to) (VP (VB be) (NP (DT any) (NN improvement))))))) (. .)))',
#   'States must show reasonable progress in their state implementation plans toward the congressionally mandated goal of returning to natural conditions in national parks and wilderness areas.',
#   'Itis not necessary for there to be any improvement.',
#   '76011',
#   '76011c',
#   'government',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( well ( it ( 's ( been ( very interesting ) ) ) ) )",
#   '( It ( ( has ( been ( very intriguing ) ) ) . ) )',
#   "(ROOT (ADJP (RB well) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (VP (VBN been) (ADJP (RB very) (JJ interesting))))))))",
#   '(ROOT (S (NP (PRP It)) (VP (VBZ has) (VP (VBN been) (ADJP (RB very) (JJ intriguing)))) (. .)))',
#   "well it's been very interesting",
#   'It has been very intriguing.',
#   '78652',
#   '78652e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( He ( ( ( started ( slowly back ) ) ( to ( the bunkhouse ) ) ) . ) )',
#   '( He ( ( ( returned slowly ) ( to ( the bunkhouse ) ) ) . ) )',
#   '(ROOT (S (NP (PRP He)) (VP (VBD started) (ADVP (RB slowly) (RB back)) (PP (TO to) (NP (DT the) (NN bunkhouse)))) (. .)))',
#   '(ROOT (S (NP (PRP He)) (VP (VBD returned) (ADVP (RB slowly)) (PP (TO to) (NP (DT the) (NN bunkhouse)))) (. .)))',
#   'He started slowly back to the bunkhouse.',
#   'He returned slowly to the bunkhouse.',
#   '44022',
#   '44022e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( and ( it ( 's ( ( ( ( ( it ( ( 's ( quite ( a bit ) ) ) ( i ( think ( ( six something ) ( is ( the state ) ) ) ) ) ) ) and ) ( ( ( ( and uh ) ( the rest ) ) ( of ( the pie ) ) ) ( goes elsewhere ) ) ) but ) ( we ( 're ( in ( ( a ( particular part ) ) ( of ( ( the state ) ( that ( 's ( ( pretty ( well off ) ) ( so ( it ( 's ( it ( 's ( like ( we ( ( get ( ( a lot ) ( of that ) ) ) ( ( back ( as far ) ) ( as ( ( local taxation ) goes ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )",
#   '( I ( ( ( do not ) ( know ( ( exactly where ) ( ( the ( local taxes ) ) go ) ) ) ) . ) )',
#   "(ROOT (PRN (CC and) (S (NP (PRP it)) (VP (VBZ 's) (S (S (NP (PRP it)) (VP (VBZ 's) (ADVP (RB quite) (NP (DT a) (RB bit))) (NP (NP (FW i)) (SBAR (S (VP (VBP think) (SBAR (S (NP (CD six) (NN something)) (VP (VBZ is) (NP (DT the) (NN state))))))))))) (CC and) (S (NP (NP (QP (CC and) (CD uh)) (DT the) (NN rest)) (PP (IN of) (NP (DT the) (NN pie)))) (VP (VBZ goes) (ADVP (RB elsewhere)))) (CC but) (S (NP (PRP we)) (VP (VBP 're) (PP (IN in) (NP (NP (DT a) (JJ particular) (NN part)) (PP (IN of) (NP (NP (DT the) (NN state)) (SBAR (WHNP (WDT that)) (S (VP (VBZ 's) (ADVP (ADVP (RB pretty) (RB well) (RB off)) (SBAR (IN so) (S (NP (PRP it)) (VP (VBZ 's) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (SBAR (IN like) (S (NP (PRP we)) (VP (VBP get) (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (DT that)))) (ADVP (ADVP (RB back) (RB as) (RB far)) (SBAR (IN as) (S (NP (JJ local) (NN taxation)) (VP (VBZ goes)))))))))))))))))))))))))))))",
#   '(ROOT (S (NP (PRP I)) (VP (VBP do) (RB not) (VP (VB know) (SBAR (WHADVP (RB exactly) (WRB where)) (S (NP (DT the) (JJ local) (NNS taxes)) (VP (VBP go)))))) (. .)))',
#   "and it's it's quite a bit i think six something is the state and and uh the rest of the pie goes elsewhere but we're in a particular part of the state that's pretty well off so it's it's like we get a lot of that back as far as local taxation goes",
#   'I do not know exactly where the local taxes go.',
#   '129069',
#   '129069n',
#   'telephone',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( They ( ( 're ( made ( from ( ( a ( secret recipe ) ) ( ( ( handed down ) ( to ( the ( present-day villagers ) ) ) ) ( by ( ( ( their ( Mallorcan ancestors ) ) , ) ( who ( ( ( came here ) ( in ( the ( early ( 17th century ) ) ) ) ) ( as ( part ( of ( an ( official ( repopulation scheme ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) . ) )",
#   '( ( ( The recipe ) ( ( passed down ) ( from ( Mallorcan ancestors ) ) ) ) ( ( is ( known ( to everyone ) ) ) . ) )',
#   "(ROOT (S (NP (PRP They)) (VP (VBP 're) (VP (VBN made) (PP (IN from) (NP (NP (DT a) (JJ secret) (NN recipe)) (VP (VBN handed) (PRT (RP down)) (PP (TO to) (NP (DT the) (JJ present-day) (NNS villagers))) (PP (IN by) (NP (NP (PRP$ their) (JJ Mallorcan) (NNS ancestors)) (, ,) (SBAR (WHNP (WP who)) (S (VP (VBD came) (ADVP (RB here)) (PP (IN in) (NP (DT the) (JJ early) (JJ 17th) (NN century))) (PP (IN as) (NP (NP (NN part)) (PP (IN of) (NP (DT an) (JJ official) (NN repopulation) (NN scheme))))))))))))))) (. .)))",
#   '(ROOT (S (NP (NP (DT The) (NN recipe)) (VP (VBN passed) (PRT (RP down)) (PP (IN from) (NP (JJ Mallorcan) (NNS ancestors))))) (VP (VBZ is) (VP (VBN known) (PP (TO to) (NP (NN everyone))))) (. .)))',
#   "They're made from a secret recipe handed down to the present-day villagers by their Mallorcan ancestors, who came here in the early 17th century as part of an official repopulation scheme.",
#   'The recipe passed down from Mallorcan ancestors is known to everyone.',
#   '144740',
#   '144740c',
#   'travel',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( yeah ( well ( you ( 're ( a ( student right ) ) ) ) ) )",
#   "( Well ( you ( ( 're ( a ( mechanics ( student right ) ) ) ) ? ) ) )",
#   "(ROOT (S (VP (VB yeah) (S (ADVP (RB well)) (NP (PRP you)) (VP (VBP 're) (NP (DT a) (NN student) (NN right)))))))",
#   "(ROOT (S (ADVP (RB Well)) (NP (PRP you)) (VP (VBP 're) (NP (DT a) (JJ mechanics) (NN student) (NN right))) (. ?)))",
#   "yeah well you're a student right",
#   "Well you're a mechanics student right?",
#   '87912',
#   '87912n',
#   'telephone',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( it ( ( ( really ( is ( ( i ( ( heard something ) ( that ( ( ( their ( supposed ( to ( be ( ( starting ( a ( huge campaign ) ) ) ( in ( ( New York ) ( about ( um ( ( ( child abuse ) and ) ( stopping ( child abuse ) ) ) ) ) ) ) ) ) ) ) ) and ) ( it ( 's ( supposed ( to ( be ( like ( ( ( it ( 's ( starting ( there ( supposed ( to ( be ( like ( a ( big ( nationwide campaign ) ) ) ) ) ) ) ) ) ) ) and ) ( you ( ( know so ) hopefully ) ) ) ) ) ) ) ) ) ) ) ) ) ( that ( will ( take off ) ) ) ) ) ) and ) ( really ( do ( something ( i ( ( do n't ) ( know ( there ( 's just ) ) ) ) ) ) ) ) ) )",
#   "( It ( ( ( 's unfortunate ) ( that ( nobody ( is ( organizing ( a ( child ( abuse campaign ) ) ) ) ) ) ) ) . ) )",
#   "(ROOT (S (NP (PRP it)) (VP (VP (ADVP (RB really)) (VBZ is) (NP (NP (FW i)) (VP (VBN heard) (NP (NN something)) (SBAR (IN that) (S (S (NP (PRP$ their)) (VP (VBD supposed) (S (VP (TO to) (VP (VB be) (VP (VBG starting) (NP (DT a) (JJ huge) (NN campaign)) (PP (IN in) (NP (NP (NNP New) (NNP York)) (PP (IN about) (NP (JJ um) (NX (NX (NN child) (NN abuse)) (CC and) (NX (JJ stopping) (NN child) (NN abuse))))))))))))) (CC and) (S (NP (PRP it)) (VP (VBZ 's) (VP (VBN supposed) (S (VP (TO to) (VP (VB be) (SBAR (IN like) (S (S (NP (PRP it)) (VP (VBZ 's) (VP (VBG starting) (S (NP (EX there)) (VP (VBN supposed) (S (VP (TO to) (VP (VB be) (PP (IN like) (NP (DT a) (JJ big) (JJ nationwide) (NN campaign))))))))))) (CC and) (S (NP (PRP you)) (VP (VBP know) (ADVP (RB so)) (ADVP (RB hopefully))))))))))))))) (SBAR (WHNP (WDT that)) (S (VP (MD will) (VP (VB take) (PRT (RP off)))))))) (CC and) (VP (ADVP (RB really)) (VBP do) (NP (NP (NN something)) (SBAR (S (NP (FW i)) (VP (VBP do) (RB n't) (VP (VB know) (SBAR (S (NP (EX there)) (VP (VBZ 's) (ADVP (RB just))))))))))))))",
#   "(ROOT (S (NP (PRP It)) (VP (VBZ 's) (ADJP (JJ unfortunate)) (SBAR (IN that) (S (NP (NN nobody)) (VP (VBZ is) (VP (VBG organizing) (NP (DT a) (NN child) (NN abuse) (NN campaign))))))) (. .)))",
#   "it really is i heard something that their supposed to be starting a huge campaign in New York about um child abuse and stopping child abuse and it's supposed to be like it's starting there supposed to be like a big nationwide campaign and you know so hopefully that will take off and really do something i don't know there's just",
#   "It's unfortunate that nobody is organizing a child abuse campaign.",
#   '128774',
#   '128774c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( Postal Service ) ( ( were ( to ( reduce ( delivery frequency ) ) ) ) . ) )',
#   '( ( The ( postal service ) ) ( ( could ( deliver ( less frequently ) ) ) . ) )',
#   '(ROOT (S (NP (NNP Postal) (NNP Service)) (VP (VBD were) (S (VP (TO to) (VP (VB reduce) (NP (NN delivery) (NN frequency)))))) (. .)))',
#   '(ROOT (S (NP (DT The) (JJ postal) (NN service)) (VP (MD could) (VP (VB deliver) (ADVP (RBR less) (RB frequently)))) (. .)))',
#   'Postal Service were to reduce delivery frequency.',
#   'The postal service could deliver less frequently.',
#   '22086',
#   '22086e',
#   'government',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( And ( ( in ( ( another shift ) ( in ( the economy ) ) ) ) ( , ( it ( ( was ( found ( ( ( that ( lamb ( could ( be ( ( raised ( ( more ( cost-effectively ( on ( ( lowland farms ) ( in ( part ( because ( of ( the ( richer ( , ( more ( nutritious ( grazing land ) ) ) ) ) ) ) ) ) ) ) ) ) ) available ) ) there ) ) ) ) ) and ) ( as ( ( a ( result ( Lakeland farms ) ) ) ( became ( less profitable ) ) ) ) ) ) ) . ) ) ) ) )',
#   '( ( ( Another shift ) ( in ( the economy ) ) ) ( ( was ( found ( to ( be ( more nutritious ) ) ) ) ) . ) )',
#   '(ROOT (S (CC And) (PP (IN in) (NP (NP (DT another) (NN shift)) (PP (IN in) (NP (DT the) (NN economy))))) (, ,) (NP (PRP it)) (VP (VBD was) (VP (VBN found) (SBAR (SBAR (IN that) (S (NP (NN lamb)) (VP (MD could) (VP (VB be) (VP (VBN raised) (S (ADJP (ADJP (RBR more) (JJ cost-effectively) (PP (IN on) (NP (NP (JJ lowland) (NNS farms)) (PP (IN in) (NP (NP (NN part)) (PP (RB because) (IN of) (NP (DT the) (JJR richer) (, ,) (JJR more) (JJ nutritious) (NN grazing) (NN land)))))))) (JJ available))) (ADVP (RB there))))))) (CC and) (SBAR (IN as) (S (NP (DT a) (NN result) (NN Lakeland) (NNS farms)) (VP (VBD became) (ADJP (RBR less) (JJ profitable)))))))) (. .)))',
#   '(ROOT (S (NP (NP (DT Another) (NN shift)) (PP (IN in) (NP (DT the) (NN economy)))) (VP (VBD was) (VP (VBN found) (S (VP (TO to) (VP (VB be) (ADJP (RBR more) (JJ nutritious))))))) (. .)))',
#   'And in another shift in the economy, it was found that lamb could be raised more cost-effectively on lowland farms in part because of the richer, more nutritious grazing land available there and as a result Lakeland farms became less profitable.',
#   'Another shift in the economy was found to be more nutritious.',
#   '110983',
#   '110983e',
#   'travel',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( The rule ) ( ( contains ( ( information ( collection requirements ) ) ( which ( will ( allow ( EPA ( to ( determine ( ( ( that ( ( ( detergent additives ) ( which ( are ( effective ( in ( controlling deposits ) ) ) ) ) ) ( are used ) ) ) and ) ( that ( ( emission ( control goals ) ) ( are realized ) ) ) ) ) ) ) ) ) ) ) ) . ) )',
#   '( ( The rule ) ( ( has ( ( data ( collection requirements ) ) ( which ( aid ( ( the EPA ) ( to ( realize ( their ( emission ( control goals ) ) ) ) ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (DT The) (NN rule)) (VP (VBZ contains) (NP (NP (NN information) (NN collection) (NNS requirements)) (SBAR (WHNP (WDT which)) (S (VP (MD will) (VP (VB allow) (S (NP (NNP EPA)) (VP (TO to) (VP (VB determine) (SBAR (SBAR (IN that) (S (NP (NP (NN detergent) (NNS additives)) (SBAR (WHNP (WDT which)) (S (VP (VBP are) (ADJP (JJ effective) (PP (IN in) (NP (VBG controlling) (NNS deposits)))))))) (VP (VBP are) (VP (VBN used))))) (CC and) (SBAR (IN that) (S (NP (NN emission) (NN control) (NNS goals)) (VP (VBP are) (VP (VBN realized))))))))))))))) (. .)))',
#   '(ROOT (S (NP (DT The) (NN rule)) (VP (VBZ has) (NP (NP (NN data) (NN collection) (NNS requirements)) (SBAR (WHNP (WDT which)) (S (VP (VB aid) (S (NP (DT the) (NNP EPA)) (VP (TO to) (VP (VB realize) (NP (PRP$ their) (NN emission) (NN control) (NNS goals)))))))))) (. .)))',
#   'The rule contains information collection requirements which will allow EPA to determine that detergent additives which are effective in controlling deposits are used and that emission control goals are realized.',
#   'The rule has data collection requirements which aid the EPA to realize their emission control goals.',
#   '73578',
#   '73578e',
#   'government',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( ( ( ( Almost ( every hill ) ) ( ( has ( to ( the northeast ) ) ) ( there ( 's ( a ( Moorish fort ) ) ) ) ) ) ; ) ( ( ( no ( fewer ( ( than four ) ruined ) ) ) fortresses ) ( guard ( ( ( ( ( ( the ( harbour entrance ) ) ; ) and ) ( ( two ( more ( , ( still ( in ( good repair ) ) ) ) ) ) ( ( the ( Atalaya ( and ( Galeras castles ) ) ) ) ( protect ( the ( sea-front arsenal ) ) ) ) ) ) , ) ( of ( ( vital importance ) ( to ( ( Spain 's ) military ) ) ) ) ) ) ) ) . )",
#   '( There ( ( ( are ( no castles ) ) ( ( Atalaya and ) Galeras ) ) . ) )',
#   "(ROOT (S (S (NP (RB Almost) (DT every) (NN hill)) (VP (VBZ has) (PP (TO to) (NP (DT the) (NN northeast))) (VP (ADVP (RB there)) (VBZ 's) (NP (DT a) (NNP Moorish) (NN fort))))) (: ;) (S (NP (QP (DT no) (JJR fewer) (IN than) (CD four) (CD ruined)) (NNS fortresses)) (VP (VBP guard) (NP (NP (DT the) (NN harbour) (NN entrance)) (: ;) (CC and) (SBAR (WHNP (WHNP (CD two)) (PP (ADVP (RBR more)) (, ,) (ADVP (RB still)) (IN in) (NP (JJ good) (NN repair)))) (S (NP (DT the) (NNP Atalaya) (CC and) (NNP Galeras) (NNS castles)) (VP (VB protect) (NP (DT the) (JJ sea-front) (NN arsenal))))) (, ,) (PP (IN of) (NP (NP (JJ vital) (NN importance)) (PP (TO to) (NP (NP (NNP Spain) (POS 's)) (NN military)))))))) (. .)))",
#   '(ROOT (S (NP (EX There)) (VP (VBP are) (NP (DT no) (NNS castles)) (NP (NNP Atalaya) (CC and) (NNP Galeras))) (. .)))',
#   "Almost every hill has to the northeast there's a Moorish fort; no fewer than four ruined fortresses guard the harbour entrance; and two more, still in good repair the Atalaya and Galeras castles protect the sea-front arsenal, of vital importance to Spain's military.",
#   'There are no castles Atalaya and Galeras.',
#   '78335',
#   '78335c',
#   'travel',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   '( ( ( Were they ) ( in there ) ) ? )',
#   '( ( ( Were they ) ( supposed ( to ( be ( in there ) ) ) ) ) ? )',
#   '(ROOT (SQ (VBD Were) (NP (PRP they)) (PP (IN in) (NP (RB there))) (. ?)))',
#   '(ROOT (SQ (VBD Were) (NP (PRP they)) (VP (VBN supposed) (S (VP (TO to) (VP (VB be) (PP (IN in) (NP (RB there))))))) (. ?)))',
#   'Were they in there?',
#   'Were they supposed to be in there?',
#   '12090',
#   '12090n',
#   'slate',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( ( Felicia 's ) Journey ) ( ( takes ( ( ( ( ( ( ( place ( behind ( ( the eyes ) ( of ( its central ) ) ) ) ) ( a ( young ( Irish girl ) ) ) ) , ) ( ( Felicia , ) ( who ( ( ( crosses ( the sea ) ) ( to ( England ( in ( a ( hopeful quest ) ) ) ) ) ) ( to ( find ( ( the father ) ( of ( her ( unborn child ) ) ) ) ) ) ) ) ) ) ; ) and ) ( ( ( ( ( the ( fat ( , ( middle-aged ( catering manager ) ) ) ) ) , ) Hiditch ) , ) ( who ( takes ( ( a ( paternal interest ) ) ( in ( ( the lass ) ( when ( it ( ( becomes clear ) ( that ( ( her ( young man ) ) ( ( has caddishly ) ( ( given her ) ( the slip ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) . ) )",
#   '( ( The woman ) ( ( ( did not ) ( care ( where ( ( the man ) ( ( was ( as long ) ) ( as ( it ( was far ) ) ) ) ) ) ) ) . ) )',
#   "(ROOT (S (NP (NP (NNP Felicia) (POS 's)) (NN Journey)) (VP (VBZ takes) (NP (NP (NP (NP (NN place)) (PP (IN behind) (NP (NP (DT the) (NNS eyes)) (PP (IN of) (NP (PRP$ its) (JJ central)))))) (NP (DT a) (JJ young) (JJ Irish) (NN girl))) (, ,) (NP (NP (NNP Felicia)) (, ,) (SBAR (WHNP (WP who)) (S (VP (VBZ crosses) (NP (DT the) (NN sea)) (PP (TO to) (NP (NP (NNP England)) (PP (IN in) (NP (DT a) (NN hopeful) (NN quest))))) (S (VP (TO to) (VP (VB find) (NP (NP (DT the) (NN father)) (PP (IN of) (NP (PRP$ her) (JJ unborn) (NN child))))))))))) (: ;) (CC and) (NP (NP (DT the) (JJ fat) (, ,) (JJ middle-aged) (JJ catering) (NN manager)) (, ,) (NP (NNP Hiditch)) (, ,) (SBAR (WHNP (WP who)) (S (VP (VBZ takes) (NP (NP (DT a) (JJ paternal) (NN interest)) (PP (IN in) (NP (NP (DT the) (NNS lass)) (SBAR (WHADVP (WRB when)) (S (NP (PRP it)) (VP (VBZ becomes) (ADJP (JJ clear)) (SBAR (IN that) (S (NP (PRP$ her) (JJ young) (NN man)) (VP (VBZ has) (ADVP (RB caddishly)) (VP (VBN given) (NP (PRP her)) (NP (DT the) (NN slip)))))))))))))))))) (. .)))",
#   '(ROOT (S (NP (DT The) (NN woman)) (VP (VBD did) (RB not) (VP (VB care) (SBAR (WHADVP (WRB where)) (S (NP (DT the) (NN man)) (VP (VBD was) (ADJP (RB as) (JJ long)) (SBAR (IN as) (S (NP (PRP it)) (VP (VBD was) (ADVP (RB far)))))))))) (. .)))',
#   "Felicia's Journey takes place behind the eyes of its central  a young Irish girl, Felicia, who crosses the sea to England in a hopeful quest to find the father of her unborn child; and the fat, middle-aged catering manager, Hiditch, who takes a paternal interest in the lass when it becomes clear that her young man has caddishly given her the slip.",
#   'The woman did not care where the man was as long as it was far.',
#   '103614',
#   '103614c',
#   'slate',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( ( In ( the crypt ) ) ( are ( interred ( ( the remains ) ( of ( Voltaire ( and ( Rousseau ( , ( ( Hugo and ) Zola ) ) ) ) ) ) ) ) ) ) ( , ( ( ( assassinated ( Socialist leader ) ) ( ( ( Jean ( Jaurys ( , ( and ( Louis Braille ) ) ) ) ) , ) ( ( the inventor ) ( of ( ( the alphabet ) ( for ( the blind ) ) ) ) ) ) ) . ) ) )',
#   '( ( ( ( ( ( ( ( ( ( The remains ) ( of ( ( Voltaire and ) Rousseau ) ) ) , ) ( ( Hugo and ) Zola ) ) , ) ( assassinated ( Socialist ( leader ( Jean Jaurys ) ) ) ) ) , ) and ) ( ( Louis Braille ) ( ( are all ) ( interred ( in ( the crypt ) ) ) ) ) ) . )',
#   '(ROOT (SINV (FRAG (S (PP (IN In) (NP (DT the) (NN crypt))) (VP (VBP are) (VP (VBN interred) (NP (NP (DT the) (NNS remains)) (PP (IN of) (NP (NNP Voltaire) (CC and) (NNP Rousseau) (, ,) (NNP Hugo) (CC and) (NNP Zola)))))))) (, ,) (VP (VBD assassinated) (NP (JJ Socialist) (NN leader))) (NP (NP (NNP Jean) (NNPS Jaurys) (, ,) (CC and) (NNP Louis) (NNP Braille)) (, ,) (NP (NP (DT the) (NN inventor)) (PP (IN of) (NP (NP (DT the) (NN alphabet)) (PP (IN for) (NP (DT the) (JJ blind))))))) (. .)))',
#   '(ROOT (S (S (NP (NP (NP (DT The) (NNS remains)) (PP (IN of) (NP (NNP Voltaire) (CC and) (NNP Rousseau)))) (, ,) (NP (NNP Hugo) (CC and) (NNP Zola)) (, ,)) (VP (VBD assassinated) (NP (JJ Socialist) (NN leader) (NNP Jean) (NNP Jaurys)))) (, ,) (CC and) (S (NP (NNP Louis) (NNP Braille)) (VP (VBP are) (RB all) (VP (VBN interred) (PP (IN in) (NP (DT the) (NN crypt)))))) (. .)))',
#   'In the crypt are interred the remains of Voltaire and Rousseau, Hugo and Zola, assassinated Socialist leader Jean Jaurys, and Louis Braille, the inventor of the alphabet for the blind.',
#   'The remains of Voltaire and Rousseau, Hugo and Zola, assassinated Socialist leader Jean Jaurys, and Louis Braille are all interred in the crypt.',
#   '37604',
#   '37604e',
#   'travel',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( ( there ( 's ( ( a uh ) ( ( a couple ) ( called ( ( um oh ) i ) ) ) ) ) ) ( ( 'm ( going ( to ( ( forgot ( his name ) ) now ) ) ) ) ( uh Dirkson ) ) )",
#   "( I ( ( ca n't ) ( remember ( their name ) ) ) )",
#   "(ROOT (SINV (S (NP (EX there)) (VP (VBZ 's) (NP (NP (DT a) (NN uh)) (SBAR (S (NP (DT a) (NN couple)) (VP (VBD called) (NP (NN um) (FW oh) (FW i)))))))) (VP (VBP 'm) (VP (VBG going) (S (VP (TO to) (VP (VB forgot) (NP (PRP$ his) (NN name)) (ADVP (RB now))))))) (NP (NNP uh) (NNP Dirkson))))",
#   "(ROOT (S (NP (PRP I)) (VP (MD ca) (RB n't) (VP (VB remember) (NP (PRP$ their) (NN name))))))",
#   "there's a uh a couple called um oh i'm going to forgot his name now uh Dirkson",
#   "I can't remember their name",
#   '28378',
#   '28378e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( Poirot ( , ( ( ( ( ( I ( ( exclaimed , ) ( with relief ) ) ) , ) and ) ( ( ( seizing him ) ( by ( both hands ) ) ) ( , ( I ( ( dragged him ) ( into ( the room ) ) ) ) ) ) ) . ) ) )',
#   '( ( ( ( Poirot ( ( was now ) back ) ) and ) ( I ( ( was sorry ) ( that ( he ( would ( ( take over ) ( what ( I ( now ( considered ( my ( own investigation ) ) ) ) ) ) ) ) ) ) ) ) ) . )',
#   '(ROOT (S (ADVP (RB Poirot)) (, ,) (S (NP (PRP I)) (VP (VBD exclaimed) (, ,) (PP (IN with) (NP (NN relief))))) (, ,) (CC and) (S (S (VP (VBG seizing) (NP (PRP him)) (PP (IN by) (NP (DT both) (NNS hands))))) (, ,) (NP (PRP I)) (VP (VBD dragged) (NP (PRP him)) (PP (IN into) (NP (DT the) (NN room))))) (. .)))',
#   '(ROOT (S (S (NP (NNP Poirot)) (VP (VBD was) (ADVP (RB now)) (ADVP (RB back)))) (CC and) (S (NP (PRP I)) (VP (VBD was) (ADJP (JJ sorry)) (SBAR (IN that) (S (NP (PRP he)) (VP (MD would) (VP (VB take) (PRT (RP over)) (SBAR (WHNP (WP what)) (S (NP (PRP I)) (ADVP (RB now)) (VP (VBD considered) (NP (PRP$ my) (JJ own) (NN investigation))))))))))) (. .)))',
#   'Poirot, I exclaimed, with relief, and seizing him by both hands, I dragged him into the room. ',
#   'Poirot was now back and I was sorry that he would take over what I now considered my own investigation. ',
#   '76592',
#   '76592c',
#   'fiction',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( The ( word aswan ) ) ( actually ( ( ( ( means ( ( ( trade or ) market ) ( in ( ancient Egyptian ) ) ) ) , ) ( signifying ( its ( most ( pre-eminent activity ) ) ) ) ) . ) ) )',
#   "( ( ( Aswan 's ) meaning ) ( ( ( has not ) ( changed ( over time ) ) ) . ) )",
#   '(ROOT (S (NP (DT The) (NN word) (NN aswan)) (ADVP (RB actually)) (VP (VBZ means) (NP (NP (NN trade) (CC or) (NN market)) (PP (IN in) (NP (JJ ancient) (NNP Egyptian)))) (, ,) (S (VP (VBG signifying) (NP (PRP$ its) (JJS most) (JJ pre-eminent) (NN activity))))) (. .)))',
#   "(ROOT (S (NP (NP (NNP Aswan) (POS 's)) (NN meaning)) (VP (VBZ has) (RB not) (VP (VBN changed) (PP (IN over) (NP (NN time))))) (. .)))",
#   'The word aswan actually means trade or market in ancient Egyptian, signifying its most pre-eminent activity.',
#   "Aswan's meaning has not changed over time.",
#   '75968',
#   '75968c',
#   'travel',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( well ( what ( ( the market ) ( can ( bear and ) ) ) ) )',
#   "( ( THe market ) ( ( ( ca n't ) ( bear ( any ( of it ) ) ) ) . ) )",
#   '(ROOT (FRAG (ADVP (RB well)) (SBAR (WHNP (WP what)) (S (NP (DT the) (NN market)) (VP (MD can) (VP (VB bear) (NP (NNP and))))))))',
#   "(ROOT (S (NP (NNP THe) (NN market)) (VP (MD ca) (RB n't) (VP (VB bear) (NP (NP (DT any)) (PP (IN of) (NP (PRP it)))))) (. .)))",
#   'well what the market can bear and',
#   "THe market can't bear any of it.",
#   '102025',
#   '102025c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( And ( ( to ( show ( ( just ( how fast ) ) ( ( ( Japan 's ) ( new rulers ) ) ( were ( catching on ) ) ) ) ) ) ( , ( ( two ( punitive expeditions ) ) ( ( were ( ( launched ( against ( ( Korea and ) China ) ) ) ( in ( ( the ( grand manner ) ) ( of ( 19th-century ( gunboat diplomacy ) ) ) ) ) ) ) . ) ) ) ) )",
#   "( ( ( Japan 's ) ( new rulers ) ) ( ( were ( ( catching on ) quickly ) ) . ) )",
#   "(ROOT (S (CC And) (S (VP (TO to) (VP (VB show) (SBAR (WHADJP (RB just) (WRB how) (JJ fast)) (S (NP (NP (NNP Japan) (POS 's)) (JJ new) (NNS rulers)) (VP (VBD were) (VP (VBG catching) (PRT (RP on))))))))) (, ,) (NP (CD two) (JJ punitive) (NNS expeditions)) (VP (VBD were) (VP (VBN launched) (PP (IN against) (NP (NNP Korea) (CC and) (NNP China))) (PP (IN in) (NP (NP (DT the) (JJ grand) (NN manner)) (PP (IN of) (NP (JJ 19th-century) (NN gunboat) (NN diplomacy))))))) (. .)))",
#   "(ROOT (S (NP (NP (NNP Japan) (POS 's)) (JJ new) (NNS rulers)) (VP (VBD were) (VP (VBG catching) (PRT (RP on)) (ADVP (RB quickly)))) (. .)))",
#   "And to show just how fast Japan's new rulers were catching on, two punitive expeditions were launched against Korea and China in the grand manner of 19th-century gunboat diplomacy.",
#   "Japan's new rulers were catching on quickly.",
#   '69555',
#   '69555e',
#   'travel',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( ( When ( ( the ( trust fund ) ) ( begins ( ( running ( cash deficits ) ) ( in 2016 ) ) ) ) ) ( , ( ( ( the government ) ( as ( a whole ) ) ) ( ( must ( ( come up ) ( with ( the ( cash ( to ( ( finance ( ( Social ( Security 's ) ) ( cash deficit ) ) ) ( by ( ( ( ( ( ( ( ( reducing ( any ( projected ( non-Social ( Security surpluses ) ) ) ) ) , ) ( borrowing ( from ( the public ) ) ) ) , ) ( raising ( other taxes ) ) ) , ) or ) ( reducing ( other ( government spending ) ) ) ) ) ) ) ) ) ) ) ) . ) ) ) )",
# ...
#   "( I ( ( ( ca n't ) ( ( say more ) ( about immigration ) ) ) . ) )",
#   "(ROOT (FRAG (CC but) (ADVP (RB anyway)) (SBAR (X (ADVP (RB well)) (NP (NN um))) (S (NP (FW i)) (VP (MD ca) (RB n't) (VP (VB think) (PP (IN of) (NP (DT a) (JJ whole) (NN lot) (JJR more))) (S (VP (TO to) (VP (VB say))))))))))",
#   "(ROOT (S (NP (PRP I)) (VP (MD ca) (RB n't) (VP (VB say) (NP (JJR more)) (PP (IN about) (NP (NN immigration))))) (. .)))",
#   "but anyway well um i can't think of a whole lot more to say",
#   "I can't say more about immigration.",
#   '1477',
#   '1477n',
#   'telephone',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( um so ) ( do ( you ( have ( a ( personal computer ) ) ) ) ) )',
#   "( You ( ( ( do n't ) ( ( ( have ( ( any computers ) ( in ( your house ) ) ) ) , ) right ) ) ? ) )",
#   '(ROOT (S (NP (NN um) (RB so)) (VP (VBP do) (SBAR (S (NP (PRP you)) (VP (VBP have) (NP (DT a) (JJ personal) (NN computer))))))))',
#   "(ROOT (S (NP (PRP You)) (VP (VBP do) (RB n't) (VP (VB have) (NP (NP (DT any) (NNS computers)) (PP (IN in) (NP (PRP$ your) (NN house)))) (, ,) (ADVP (RB right)))) (. ?)))",
#   'um so do you have a personal computer',
#   "You don't have any computers in your house, right?",
#   '10334',
#   '10334c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( what ( ( 'd they ) ( do ( for ( that ( did ( they ( have ( to ( cast ( it and ) ) ) ) ) ) ) ) ) ) )",
#   '( ( What method ) ( ( ( did they ) ( employ ( to ( get ( ( ( that done ) ; ) ( was ( ( the thing ) ( ( ( poured ( into ( a mold ) ) ) or ) pressed ) ) ) ) ) ) ) ) ? ) )',
#   "(ROOT (SBARQ (WHNP (WP what)) (SQ (MD 'd) (NP (PRP they)) (VP (VB do) (SBAR (IN for) (S (NP (DT that)) (VP (VBD did) (SBAR (S (NP (PRP they)) (VP (VBP have) (S (VP (TO to) (VP (VB cast) (S (NP (PRP it)) (VP (VB and))))))))))))))))",
#   '(ROOT (SBARQ (WHNP (WDT What) (NN method)) (SQ (VBD did) (NP (PRP they)) (VP (VB employ) (S (VP (TO to) (VP (VB get) (NP (NP (DT that)) (VP (VBN done)) (: ;) (SBAR (S (VP (VBD was) (NP (NP (DT the) (NN thing)) (VP (VP (VBN poured) (PP (IN into) (NP (DT a) (NN mold)))) (CC or) (VP (VBN pressed))))))))))))) (. ?)))',
#   "what'd they do for that did they have to cast it and",
#   'What method did they employ to get that done; was the thing poured into a mold or pressed?',
#   '132012',
#   '132012n',
#   'telephone',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( um ( yeah ( ( ( ( but ( you ( need ( to ( continue ( to ( ( read so ) you ) ) ) ) ) ) ) ( you can ) ) ( people ( learn ( to read ) ) ) ) ( you know ) ) ) )',
#   '( Nobody ( ( needs ( to ( read ( at all ) ) ) ) . ) )',
#   '(ROOT (S (NP (NN um)) (VP (VBP yeah) (S (S (CC but) (NP (PRP you)) (VP (VBP need) (S (VP (TO to) (VP (VB continue) (S (VP (TO to) (VP (VB read) (ADVP (RB so)) (NP (PRP you)))))))))) (S (NP (PRP you)) (VP (MD can))) (S (NP (NNS people)) (VP (VBP learn) (S (VP (TO to) (VP (VB read)))))) (S (NP (PRP you)) (VP (VBP know)))))))',
#   '(ROOT (S (NP (NN Nobody)) (VP (VBZ needs) (S (VP (TO to) (VP (VB read) (ADVP (IN at) (DT all)))))) (. .)))',
#   'um yeah but you need to continue to read so you you can people learn to read you know',
#   'Nobody needs to read at all.',
#   '10956',
#   '10956c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( ( ( ( ( Other distinctions ) ( ( ( are possible ) , ) ( such ( as ( ( bulk and ) nonbulk ) ) ) ) ) , ) but ) ( ( the ( speed distinction ) ) ( would ( seem ( to dominate ) ) ) ) ) . )',
#   '( ( Other distinctions ) ( ( ( are not ) possible ) , ) )',
#   '(ROOT (S (S (NP (JJ Other) (NNS distinctions)) (VP (VBP are) (ADJP (JJ possible)) (, ,) (PP (JJ such) (PP (IN as) (NP (NN bulk) (CC and) (NN nonbulk)))))) (, ,) (CC but) (S (NP (DT the) (NN speed) (NN distinction)) (VP (MD would) (VP (VB seem) (S (VP (TO to) (VP (VB dominate))))))) (. .)))',
#   '(ROOT (S (NP (JJ Other) (NNS distinctions)) (VP (VBP are) (RB not) (ADJP (JJ possible))) (, ,)))',
#   'Other distinctions are possible, such as bulk and nonbulk, but the speed distinction would seem to dominate.',
#   'Other distinctions are not possible, ',
#   '83647',
#   '83647c',
#   'government',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( Youth ( ( is ( ( a failing ) ( ( only ( too easily ) ) outgrown ) ) ) . ) )',
#   '( ( ( The idea ) ( of youth ) ) ( ( is ( ( a fault ) ( that ( is ( ( overcome easily ) ( by growth ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (NNP Youth)) (VP (VBZ is) (NP (NP (DT a) (VBG failing)) (VP (ADVP (RB only) (RB too) (RB easily)) (VBN outgrown)))) (. .)))',
#   '(ROOT (S (NP (NP (DT The) (NN idea)) (PP (IN of) (NP (NN youth)))) (VP (VBZ is) (NP (NP (DT a) (NN fault)) (SBAR (WHNP (WDT that)) (S (VP (VBZ is) (VP (VBN overcome) (ADVP (RB easily)) (PP (IN by) (NP (NN growth))))))))) (. .)))',
#   'Youth is a failing only too easily outgrown.',
#   'The idea of youth is a fault that is overcome easily by growth.',
#   '108610',
#   '108610e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( ( i i ) ( ( ( it ( 's ( okay ( to ( ( ( watch ( people ( go out ) ) ) and ) ( break ( their legs ) ) ) ) ) ) ) but ) ( i ( ( 'm not ) ( going ( to ( ( ( ( climb ( on ( ( a couple ) ( of ( pieces ( of wood ) ) ) ) ) ) and ) ( go ( ( racing down ) ( a ( slick ( mountain side ) ) ) ) ) ) i ) ) ) ) ) ) ) ( mean ( that 's ) ) )",
#   "( ( I ( would ( love ( to ( go ( mountain sliding ) ) ) ) ) ) ( , ( it ( ( 's ( my ( life dream ) ) ) . ) ) ) )",
#   "(ROOT (S (NP (NP (FW i) (FW i)) (SBAR (S (S (NP (PRP it)) (VP (VBZ 's) (ADJP (JJ okay) (S (VP (TO to) (VP (VP (VB watch) (S (NP (NNS people)) (VP (VB go) (PRT (RP out))))) (CC and) (VP (VB break) (NP (PRP$ their) (NNS legs))))))))) (CC but) (S (NP (FW i)) (VP (VBP 'm) (RB not) (VP (VBG going) (S (VP (TO to) (VP (VP (VB climb) (PP (IN on) (NP (NP (DT a) (NN couple)) (PP (IN of) (NP (NP (NNS pieces)) (PP (IN of) (NP (NN wood)))))))) (CC and) (VP (VB go) (S (VP (VBG racing) (PRT (RP down)) (NP (DT a) (JJ slick) (NN mountain) (NN side))))) (NP (FW i))))))))))) (VP (VBP mean) (SBAR (IN that) (S (VP (VBZ 's)))))))",
#   "(ROOT (S (S (NP (PRP I)) (VP (MD would) (VP (VB love) (S (VP (TO to) (VP (VB go) (NP (NP (NN mountain)) (VP (VBG sliding))))))))) (, ,) (NP (PRP it)) (VP (VBZ 's) (NP (PRP$ my) (NN life) (NN dream))) (. .)))",
#   "i i it's okay to watch people go out and break their legs but i'm not going to climb on a couple of pieces of wood and go racing down a slick mountain side i mean that's",
#   "I would love to go mountain sliding, it's my life dream.",
#   '144623',
#   '144623c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   '( ( ( ( ( ( The fire ) burns ) , ) and ) ( it destroys ) ) . )',
#   '( ( The fire ) ( ( destroyed it ) . ) )',
#   '(ROOT (S (S (NP (DT The) (NN fire)) (VP (VBZ burns))) (, ,) (CC and) (S (NP (PRP it)) (VP (VBZ destroys))) (. .)))',
#   '(ROOT (S (NP (DT The) (NN fire)) (VP (VBD destroyed) (NP (PRP it))) (. .)))',
#   'The fire burns, and it destroys. ',
#   'The fire destroyed it. ',
#   '85687',
#   '85687e',
#   'fiction',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( ( ( WRITE-OFF - ) ( An ( action ( to ( ( remove ( an amount ) ) ( from ( ( an ( entity 's ) ) ( ( assets or ) ( financial resources ) ) ) ) ) ) ) ) ) . )",
#   '( ( Write offs ) ( ( are ( used ( to ( remove ( financial information ) ) ) ) ) . ) )',
#   "(ROOT (NP (NP (NNP WRITE-OFF)) (: -) (NP (DT An) (NN action) (S (VP (TO to) (VP (VB remove) (NP (DT an) (NN amount)) (PP (IN from) (NP (NP (DT an) (NN entity) (POS 's)) (NX (NX (NNS assets)) (CC or) (NX (JJ financial) (NNS resources))))))))) (. .)))",
#   '(ROOT (S (NP (JJ Write) (NNS offs)) (VP (VBP are) (VP (VBN used) (S (VP (TO to) (VP (VB remove) (NP (JJ financial) (NN information))))))) (. .)))',
#   "WRITE-OFF -An action to remove an amount from an entity's assets or financial resources.",
#   'Write offs are used to remove financial information. ',
#   '23650',
#   '23650e',
#   'government',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( ( From ( ( a population ) ( of 20,000 ) ) ) ( it ( ( has ( ( ( grown ( into ( ( a metropolis ) ( of ( 2.5 million ) ) ) ) ) , ) ( with ( ( ( ( tightly clustered ) skyscrapers ) and ) ( some ( of ( ( China 's ) ( highest ( groseng industries ) ) ) ) ) ) ) ) ) . ) ) )",
#   '( ( Its population ) ( ( has ( increased ( by ( over ( two million ) ) ) ) ) . ) )',
#   "(ROOT (S (PP (IN From) (NP (NP (DT a) (NN population)) (PP (IN of) (NP (CD 20,000))))) (NP (PRP it)) (VP (VBZ has) (VP (VBN grown) (PP (IN into) (NP (NP (DT a) (NNS metropolis)) (PP (IN of) (NP (QP (CD 2.5) (CD million)))))) (, ,) (PP (IN with) (NP (NP (ADJP (RB tightly) (VBN clustered)) (NNS skyscrapers)) (CC and) (NP (NP (DT some)) (PP (IN of) (NP (NP (NNP China) (POS 's)) (JJS highest) (VBG groseng) (NNS industries)))))))) (. .)))",
#   '(ROOT (S (NP (PRP$ Its) (NN population)) (VP (VBZ has) (VP (VBN increased) (PP (IN by) (NP (QP (RB over) (CD two) (CD million)))))) (. .)))',
#   "From a population of 20,000 it has grown into a metropolis of 2.5 million, with tightly clustered skyscrapers and some of China's highest groseng industries.",
#   'Its population has increased by over two million.',
#   '141082',
#   '141082e',
#   'travel',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['neutral',
#   "( ( ( ( ( ( The titles ) alone ) -- ) ( ( ( Mars ( Probe ( Finds Kittens ) ) ) and ) ( ( ( Schredinger 's ) Cat ) ( -LRB- ( ( which ( covers ( ( ( ( Sacajawea 's ) ( Rain Bonnet ) ) and ) ( ( Wittgenstein 's ) Banana ) ) ) ) -RRB- ) ) ) ) ) -- ) ( ( display ( ( ( Martin 's ) knack ) ( for ( goofy parody ) ) ) ) . ) )",
#   "( ( ( Martin 's ) works ) ( ( are ( enjoyed ( by many ) ) ) . ) )",
#   "(ROOT (S (NP (NP (NP (DT The) (NNS titles)) (ADVP (RB alone))) (: --) (NP (NP (NNP Mars) (NNP Probe) (NNPS Finds) (NNP Kittens)) (CC and) (NP (NP (NP (NNP Schredinger) (POS 's)) (NN Cat)) (PRN (-LRB- -LRB-) (SBAR (WHNP (WDT which)) (S (VP (VBZ covers) (NP (NP (NP (NNP Sacajawea) (POS 's)) (NN Rain) (NN Bonnet)) (CC and) (NP (NP (NNP Wittgenstein) (POS 's)) (NNP Banana)))))) (-RRB- -RRB-)))) (: --)) (VP (VBP display) (NP (NP (NP (NNP Martin) (POS 's)) (NN knack)) (PP (IN for) (NP (JJ goofy) (NN parody))))) (. .)))",
#   "(ROOT (S (NP (NP (NNP Martin) (POS 's)) (NNS works)) (VP (VBP are) (VP (VBN enjoyed) (PP (IN by) (NP (JJ many))))) (. .)))",
#   "The titles alone--Mars Probe Finds Kittens and Schredinger's Cat (which covers Sacajawea's Rain Bonnet and Wittgenstein's Banana)--display Martin's knack for goofy parody.",
#   "Martin's works are enjoyed by many.",
#   '106962',
#   '106962n',
#   'slate',
#   'neutral',
#   '',
#   '',
#   '',
#   ''],
#  ['entailment',
#   "( and ( i ( ( talked ( to ( someone ( about ( the uh ) ) ) ) ) ( ( the ( uh ( education system ) ) ) ( ( ( i ( forget ( ( ( ( exactly what ) ( ( the focus ) ( was ( on ( that one ) ) ) ) ) but ) ( that ( was ( fairly interesting ) ) ) ) ) ) and ) ( i ( 've ( talked ( to ( somebody ( about ( credit ( card usage ) ) ) ) ) ) ) ) ) ) ) ) )",
#   '( I ( ( ( talked ( to someone ) ) ( about ( the ( education ( system ( and ( credit ( card usage ) ) ) ) ) ) ) ) . ) )',
#   "(ROOT (FRAG (CC and) (NP (NP (FW i)) (SBAR (S (VP (VBD talked) (PP (TO to) (NP (NP (NN someone)) (PP (IN about) (NP (DT the) (NN uh))))) (NP (NP (DT the) (JJ uh) (NN education) (NN system)) (SBAR (S (S (NP (FW i)) (VP (VBP forget) (SBAR (SBAR (WHADJP (RB exactly) (WP what)) (S (NP (DT the) (NN focus)) (VP (VBD was) (PP (IN on) (NP (DT that) (NN one)))))) (CC but) (SBAR (WHNP (WDT that)) (S (VP (VBD was) (ADJP (RB fairly) (JJ interesting)))))))) (CC and) (S (NP (FW i)) (VP (VBP 've) (VP (VBN talked) (PP (TO to) (NP (NP (NN somebody)) (PP (IN about) (NP (NN credit) (NN card) (NN usage)))))))))))))))))",
#   '(ROOT (S (NP (PRP I)) (VP (VBD talked) (PP (TO to) (NP (NN someone))) (PP (IN about) (NP (DT the) (NN education) (NN system) (CC and) (NN credit) (NN card) (NN usage)))) (. .)))',
#   "and i talked to someone about the uh the uh education system i forget exactly what the focus was on that one but that was fairly interesting and i've talked to somebody about credit card usage",
#   'I talked to someone about the education system and credit card usage.',
#   '18010',
#   '18010e',
#   'telephone',
#   'entailment',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( so ( ( let ( 's ( ( see what ) well ) ) ) ( ( ( what kind ) ( of music ) ) ( do ( you ( not like ) ) ) ) ) )",
#   '( ( Tell me ) ( about ( ( all ( the music ) ) ( you ( love ( listening to ) ) ) ) ) )',
#   "(ROOT (SINV (ADVP (RB so)) (VP (VBD let) (SBAR (S (NP (PRP 's)) (VP (VBP see) (NP (WP what)) (ADVP (RB well)))))) (SBAR (WHNP (WP what) (NN kind) (PP (IN of) (NP (NN music)))) (S (VP (VBP do) (S (NP (PRP you)) (RB not) (VP (VB like))))))))",
#   '(ROOT (S (VP (VB Tell) (NP (PRP me)) (PP (IN about) (NP (NP (PDT all) (DT the) (NN music)) (SBAR (S (NP (PRP you)) (VP (VBP love) (S (VP (VBG listening) (PP (TO to))))))))))))',
#   "so let's see what well what kind of music do you not like",
#   'Tell me about all the music you love listening to ',
#   '106262',
#   '106262c',
#   'telephone',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   "( ( ( ( ( They ( -- ( ( ( hey , ) ( what ( ( ( 's that ) ? ) '' ) ) ) ( He ( was ( looking up ) ) ) ) ) ) , ) and ) ( Hanson ( followed ( his gaze ) ) ) ) . )",
#   '( He ( ( ( ( ( looked down ) ( at ( the ground ) ) ) , ) ( while ( Hanson ( looked up ) ) ) ) . ) )',
#   "(ROOT (S (S (NP (PRP They)) (: --) (S (VP (VBP hey) (, ,) (SBARQ (WHNP (WP what)) (SQ (VBZ 's) (NP (DT that))) (. ?) ('' '')))) (NP (PRP He)) (VP (VBD was) (VP (VBG looking) (PRT (RP up))))) (, ,) (CC and) (S (NP (NNP Hanson)) (VP (VBD followed) (NP (PRP$ his) (NN gaze)))) (. .)))",
#   '(ROOT (S (NP (PRP He)) (VP (VBD looked) (PRT (RP down)) (PP (IN at) (NP (DT the) (NN ground))) (, ,) (SBAR (IN while) (S (NP (NNP Hanson)) (VP (VBD looked) (PRT (RP up)))))) (. .)))',
#   'They--hey, what\'s that?"  He was looking up, and Hanson followed his gaze.',
#   'He looked down at the ground, while Hanson looked up.',
#   '139449',
#   '139449c',
#   'fiction',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( Or ( ( ( does ( cold iron ) ) ( ruin ( ( ( ( ( ( your conjuring ) ( here ? ) ) ( ( Sather Karf ) ( snorted ( in ( obvious disgust ) ) ) ) ) , ) but ) ( Bork ( only grinned ) ) ) ) ) . ) )',
#   '( ( Sather Karf ) ( ( has ( ( no questions ) ( regarding ( cold ( ( iron and ) conjuring ) ) ) ) ) . ) )',
#   '(ROOT (SQ (CC Or) (VBZ does) (NP (JJ cold) (NN iron)) (VP (VB ruin) (S (S (FRAG (NP (PRP$ your) (NN conjuring)) (ADVP (RB here)) (. ?)) (NP (NNP Sather) (NNP Karf)) (VP (VBD snorted) (PP (IN in) (NP (JJ obvious) (NN disgust))))) (, ,) (CC but) (S (NP (NNP Bork)) (ADVP (RB only)) (VP (VBD grinned))))) (. .)))',
#   '(ROOT (S (NP (NNP Sather) (NNP Karf)) (VP (VBZ has) (NP (NP (DT no) (NNS questions)) (PP (VBG regarding) (NP (JJ cold) (NN iron) (CC and) (NN conjuring))))) (. .)))',
#   'Or does cold iron ruin your conjuring here?  Sather Karf snorted in obvious disgust, but Bork only grinned.',
#   'Sather Karf has no questions regarding cold iron and conjuring.',
#   '92621',
#   '92621c',
#   'fiction',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ['contradiction',
#   '( ( ( 5 million ) Americans ) ( ( ( living ( in ( households ( with ( an income ) ) ) ) ) ( below ( the ( poverty level ) ) ) ) . ) )',
#   '( ( 5 ( millun Americans ) ) ( make ( ( too much ) money ) ) )',
#   '(ROOT (S (NP (QP (CD 5) (CD million)) (NNPS Americans)) (VP (VBD living) (PP (IN in) (NP (NP (NNS households)) (PP (IN with) (NP (DT an) (NN income))))) (PP (IN below) (NP (DT the) (NN poverty) (NN level)))) (. .)))',
#   '(ROOT (S (NP (CD 5) (JJ millun) (NNS Americans)) (VP (VBP make) (NP (ADJP (RB too) (JJ much)) (NN money)))))',
#   '5 million Americans living in households with an income below the poverty level.',
#   '5 millun Americans make too much money',
#   '122436',
#   '122436c',
#   'government',
#   'contradiction',
#   '',
#   '',
#   '',
#   ''],
#  ...]

# %%
lines
# Out:
# [['/'],
#  ['h'],
#  ['o'],
#  ['m'],
#  ['e'],
#  ['/'],
#  ['m'],
#  ['i'],
#  ['c'],
#  ['h'],
#  ['a'],
#  ['l'],
#  ['/'],
#  ['D'],
#  ['e'],
#  ['s'],
#  ['k'],
#  ['t'],
#  ['o'],
#  ['p'],
#  ['/'],
#  ['N'],
#  ['L'],
#  ['P'],
#  ['_'],
#  ['P'],
#  ['R'],
#  ['O'],
#  ['J'],
#  ['E'],
#  ['C'],
#  ['T'],
#  ['/'],
#  ['d'],
#  ['a'],
#  ['t'],
#  ['a'],
#  ['/'],
#  ['m'],
#  ['u'],
#  ['l'],
#  ['t'],
#  ['i'],
#  ['n'],
#  ['l'],
#  ['i'],
#  ['_'],
#  ['1'],
#  ['.'],
#  ['0'],
#  ['_'],
#  ['t'],
#  ['r'],
#  ['a'],
#  ['i'],
#  ['n'],
#  ['.'],
#  ['t'],
#  ['x'],
#  ['t']]

# %%
df = pd.read_csv(train_dataset_path, delimiter=" ")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-fcb945ffc776> in <module>
# ----> 1 df = pd.read_csv(train_dataset_path, delimiter=" ")
#
# ~/miniconda3/envs/machinelearning/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/miniconda3/envs/machinelearning/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/miniconda3/envs/machinelearning/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/miniconda3/envs/machinelearning/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 141 fields in line 3, saw 511
